# %% [markdown]
# EGID test

# %%
import requests
import json

# Standalone script: single EGID lookup and full JSON print

EGID = 1

url = f"https://api3.geo.admin.ch/rest/services/ech/MapServer/ch.bfs.gebaeude_wohnungs_register/{EGID}_0"
params = {
    "f": "json",
    "lang": "de",
}

response = requests.get(url, params=params, timeout=10)

print(f"Status code: {response.status_code}")
response.raise_for_status()  # stop here if error

data = response.json()

# Pretty-print the entire response
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# Current columns (excluding geometry):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # ── 6b. INTERACTIVELY DROP UNWANTED COLUMNS ───────────────────────────────────
#       2 print("\nCurrent columns (excluding geometry):")
# ----> 3 non_geom = [c for c in gdf_clean.columns if c != "geometry"]
#       4 for i, col in enumerate(non_geom):
#       5     print(f"  [{i}] {col}")
#
# NameError: name 'gdf_clean' is not defined

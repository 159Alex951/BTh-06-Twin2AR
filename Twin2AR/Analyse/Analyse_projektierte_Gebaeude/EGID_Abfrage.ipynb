# %% [markdown]
# EGID test

# %%
import requests
import json

# Standalone script: single EGID lookup and full JSON print

EGID = 1

url = f"https://api3.geo.admin.ch/rest/services/ech/MapServer/ch.bfs.gebaeude_wohnungs_register/{EGID}_0"
params = {
    "f": "json",
    "lang": "de",
}

response = requests.get(url, params=params, timeout=10)

print(f"Status code: {response.status_code}")
response.raise_for_status()  # stop here if error

data = response.json()

# Pretty-print the entire response
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# Status code: 200
# {
#   "feature": {
#     "featureId": "1_0",
#     "bbox": [
#       676523.0,
#       235843.0,
#       676523.0,
#       235843.0
#     ],
#     "layerBodId": "ch.bfs.gebaeude_wohnungs_register",
#     "layerName": "GWR: Gebäudestatus",
#     "id": "1_0",
#     "geometry": {
#       "x": 676523.0,
#       "y": 235843.0,
#       "spatialReference": {
#         "wkid": 21781
#       }
#     },
#     "attributes": {
#       "egid": "1",
#       "strname_deinr": "Grossholzerstrasse 20",
#       "plz_plz6": "8910/891000",
#       "ggdename": "Affoltern am Albis",
#       "ggdenr": 2,
#       "gexpdat": "17.03.2026",
#       "gdekt": "ZH",
#       "egrid": "CH418983287761",
#       "lgbkr": 0,
#       "lparz": "4498",
#       "lparzsx": null,
#       "ltyp": null,
#       "gebnr": "22",
#       "gbez": "",
#       "gkode": 2676523.0,
#       "gkodn": 1235843.0,
#       "gksce": 904,
#       "gstat": 1004,
#       "gkat": 1040,
#       "gklas": 1271,
#       "gbauj": 1984,
#       "gbaum": null,
#       "gbaup": 8016,
#       "gabbj": null,
#       "garea": 1500,
#       "gvol": null,
#       "gvolnorm": null,
#       "gvolsce": null,
#       "gastw": 2,
#       "ganzwhg": 2,
#       "gazzi": null,
#       "gschutzr": null,
#       "gebf": null,
#       "gwaerzh1": 7410,
#       "genh1": 7598,
#       "gwaersceh1": 864,
#       "gwaerdath1": "31.12.2021",
#       "gwaerzh2": 7400,
#       "genh2": 7500,
#       "gwaersceh2": 860,
#       "gwaerdath2": "29.11.2001",
#       "gwaerzw1": 7630,
#       "genw1": 7530,
#       "gwaerscew1": 860,
#       "gwaerdatw1": "29.11.2001",
#       "gwaerzw2": 7600,
#       "genw2": 7500,
#       "gwaerscew2": 860,
#       "gwaerdatw2": "29.11.2001",
#       "edid": "0",
#       "egaid": 100000334,
#       "deinr": "20",
#       "esid": 10000533,
#       "strname": [
#         "Grossholzerstrasse"
#       ],
#       "strnamk": [
#         "Grossholzerstr."
#       ],
#       "strindx": [
#         "Gro"
#       ],
#       "strsp": [
#         "DE"
#       ],
#       "stroffiziel": "1",
#       "dplz4": 8910,
#       "dplzz": 0,
#       "dplzname": "Affoltern am Albis",
#       "dkode": 2676523.0,
#       "dkodn": 1235843.0,
#       "doffadr": 1,
#       "dexpdat": "17.03.2026",
#       "ewid": [
#         "1",
#         "3"
#       ],
#       "whgnr": [
#         "1",
#         "101"
#       ],
#       "wstwk": [
#         3100,
#         3101
#       ],
#       "wmehrg": [
#         1,
#         0
#       ],
#       "weinr": [
#         null,
#         null
#       ],
#       "wbez": [
#         null,
#         null
#       ],
#       "wstat": [
#         3004,
#         3004
#       ],
#       "wexpdat": [
#         "2026-03-17T00:00:00",
#         "2026-03-17T00:00:00"
#       ],
#       "wbauj": [
#         1999,
#         1999
#       ],
#       "wabbj": [
#         null,
#         null
#       ],
#       "warea": [
#         40,
#         120
#       ],
#       "wazim": [
#         1,
#         4
#       ],
#       "wkche": [
#         1,
#         1
#       ],
#       "label": "Grossholzerstrasse 20"
#     }
#   }
# }
